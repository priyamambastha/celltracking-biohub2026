# %%
# write code for cellpose 3d instance segmentation
# uv add cellpose3d

# 44b6_0113de3b.geff
# 44b6_0113de3b.zarr

# qualitatively assess it.

# %% [markdown]
# # Methodology

# %% [markdown]
# 1. Identify samples that have centroid labels.
# 2. Crop the 3D volume of these centroid labels.
# 3. Apply copy-paste augmentation of these cropped cell nodes.
# 4. Train model for keypoint detection of centroids.
